# %% [markdown]
# # Libraries import

# %%
import tensorflow as tf 
import numpy as np
import os 
import cv2
import random
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Input,Flatten,Dense,Dropout,Lambda
from tensorflow.keras.regularizers import l2

# %% [markdown]
# # Configuration

# %%
# Defining image dimension
img_width = 128
img_height = 128

# Defining size of face embedding vector
Embedding_size = 128

# The number of triplets per training step
Batch_size = 32

# Data set path
dataset_path = 'celebrity'
train_path = os.path.join(dataset_path,"Train")
test_path = os.path.join(dataset_path,"Test")

# %% [markdown]
# # Data Loading and Prepration

# %%
def load_data(path):
    """ Loads images and organizes them by person """
    people = [d for d in os.listdir(path) if os.path.isdir(os.path.join(path,d))]
    data = {}
    for person in people:
        person_path = os.path.join(path,person)
        images = [os.path.join(person_path,f) for f in os.listdir(person_path)]
        data[person] = images

    return data


def preprocess_image(filepath):
    """ Reads , resizes, and normalizes an image."""
    image = cv2.imread(filepath)
    if image is None:
        return None
    image = cv2.resize(image,(img_width,img_height))
    image = image.astype('float32')/255.0
    return image

# %% [markdown]
# # Model Architecture

# %%
def create_embedding_model(input_shape):
    """ 
        Creates a ResNet50-base model for generating face embeddings.
    
    """
    # We removed the dense layers that means fully connected layers that are on top
    base_model = ResNet50(weights='imagenet',include_top=False,input_shape=input_shape)

    # Freeze the layers of the pre-trained model
    # because we don't want to train from scratch
    for layers in base_model.layers:
        layers.trainable = False

    # Add Embedding Layers
    x = base_model.output
    x = Flatten()(x)
    x = Dense(512,activation = 'relu',kernel_regularizer = l2(0.01))(x)
    x = Dropout(0.5)(x)

    # The Final Embedding Layer
    embedding = Dense(Embedding_size,activation=None)(x)

    # Create the model
    model = Model(inputs = base_model.input,outputs = embedding)

    return model

# %% [markdown]
# # Training With Triplet loss

# %%
def get_triplet_loss(margin=0.2):
    """ 
        Defines the Triplet Loss Function
    """
    def triplet_loss(y_true,y_pred):
        anchor = y_pred[:, :Embedding_size]
        positive = y_pred[:,Embedding_size:Embedding_size*2]
        negative = y_pred[:, Embedding_size*2:]

        # Calculate the distance between the anchor and the postive image
        pos_dist = tf.reduce_sum(tf.square(anchor - positive),axis = -1)

        # Calculate the distance between the anchor and the negative image
        neg_dist = tf.reduce_sum(tf.square(anchor - negative),axis = -1)
    
        # Calculate the loss using formula max(0,pos_dist - neg_dist + margin)
        # if negative_dist is greater that means the model is learning right in that case the formula will choose 0
        # if postive+margin is greater than negative then it will chosse the difference between these that will be the loss

        loss = tf.maximum(pos_dist - neg_dist + margin, 0.0)
        return tf.reduce_mean(loss)
    
    return triplet_loss

def generate_triplets(data,num_triplets,embedding_model):
    """ Generates a batch of triplets for training """
    triplets = []
    people = list(data.keys())
    for _ in range(num_triplets):
        # Anchor and Positive images are from teh same person
        person_anchor = random.choice(people)
        images_same_person = data[person_anchor]

        # Ensure there are at least two images for the same person
        if len(images_same_person)<2:
            continue

        anchor_path , positive_path = random.sample(images_same_person,2)

        # Negative image is from a different Person
        people_other = [p for p in people if p!= person_anchor]
        if not people_other:
            continue

        person_negative = random.choice(people_other)
        negative_path = random.choice(data[person_negative])


        # Preprocessing Images

        anchor_img = preprocess_image(anchor_path)
        positive_img = preprocess_image(positive_path)
        negative_img = preprocess_image(negative_path)

        if anchor_img is not None and positive_img is not None and negative_img is not None:
            triplets.append((anchor_img,positive_img,negative_img))

    # Convert to numpy array for training
    if not triplets:
        return np.zeros((1,img_width,img_height,3)),np.zeros((1,img_width,img_height,3)),np.zeros((1,img_width,img_height,3))
    
    anchors = np.array([t[0] for t in triplets])
    positives = np.array([t[1] for t in triplets])
    negatives = np.array([t[2] for t in triplets])

    return anchors,positives,negatives

# %% [markdown]
# # Face Recognition

# %%
def get_embedding(model,image_path):
    """ Generates and embedding for a single image."""
    image = preprocess_image(image_path)
    image = np.expand_dims(image,axis = 0)
    embedding = model.predict(image)
    return embedding[0]

def verify_faces(model,data,threshold=0.5):
    """ Performs face verification on a test set."""
    people  = list(data.keys())

    print("\n-------- Verifying Faces ------------")

    # Generate anchor embeddings for each person in the test set
    anchor_embeddings = {}
    for person in people:
        images = data[person]
        if images:
            # use the first image of a person as a reference anchor
            anchor_path = images[0]
            anchor_embeddings[person] = get_embedding(model,anchor_path)

    for person_test in people:
        print(f"\nVerifying images for {person_test} : ")
        # Get all images for a person from teh test set
        test_paths = data[person_test][1:] # use remaining images for testing

        for test_path in test_paths:
            test_embedding = get_embedding(model,test_path)

            # Compare test image to its own person's anchor

            distance = np.linalg.norm(test_embedding-anchor_embeddings[person_test])

            if distance < threshold:
                print(f" Mathch : {test_path.split("/")[-1]} -> Same Person ({person_test}) . Distance : {distance:.4f}")
            else:
                print(f"  No Match: {test_path.split('/')[-1]} -> Different person. Distance: {distance:.4f}")


def identify_person(model,gallery_data,unknown_image_path, threshold = 0.5):
    """ 
        Identifies a person from a new image against a gallery of known faces.
    
        Args:
            model (tf.keras.Model): The trained embedding model.
            gallery_data (dict): A dictionary of known people and their image paths.
            unknown_image_path (str): The file path to the new, unknown image.
            threshold (float): The maximum distance for a positive match.
        
        Returns:
            str: The name of the identified person or "Unknown".
        
    
    """
    print(f"\n--- Identifying {os.path.basename(unknown_image_path)} ---")

    # 1. Generate embedding for the unknown face
    unknown_embedding = get_embedding(model,unknown_image_path)
    if unknown_embedding is None:
        return "Unknown"
    
    # 2. Generate a gallery of embedding for know faces
    known_embeddings = {}
    for person, images in gallery_data.items():
        # use the first image of each person as the reference
        if images:
            known_embeddings[person] = get_embedding(model,images[0])

    #3. Find the Closes match
    best_match_person = "Unknown"
    min_distance = float('inf')

    for person, embedding in known_embeddings.items():
        if embedding is not None:

            distance = np.linalg.norm(unknown_embedding - embedding)

            # Check if this is the closest match so far
            if distance < min_distance:
                min_distance = distance
                best_match_person = person

    #4. Check against the threshold
    if min_distance<threshold:
        print(f" Best Mathc : {best_match_person} with distace {min_distance:.4f} (Below Threshold)")
        return best_match_person
    else:
        print(f"  No match found. Closest is {best_match_person} with distance {min_distance:.4f} (Above threshold)")
        return "Unknown"

# %% [markdown]
# # Main Execution

# %%
if __name__ == "__main__":
    # Load the data from Train and Test Folders
    train_data = load_data(train_path)
    test_data = load_data(test_path)

    # Create the embedding model
    embedding_model = create_embedding_model(input_shape = (img_width,img_height,3))

    # Create the training model taht takes three inputs and passes them to the embedding model
    input_anchor = Input(shape=(img_width,img_height,3),name = "input_anchor")
    input_positive = Input(shape=(img_width,img_height,3),name = "input_positive")
    input_negative = Input(shape=(img_width, img_height, 3), name='input_negative')
    
    embedding_anchor = embedding_model(input_anchor)
    embedding_positive = embedding_model(input_positive)
    embedding_negative = embedding_model(input_negative)

    # Concatenate the embeddings for the triplet loss function

    merged_output = Lambda(lambda x: tf.concat(x, axis = 1))([embedding_anchor, embedding_positive, embedding_negative])

    triplet_model = Model(inputs=[input_anchor, input_positive, input_negative], outputs=merged_output)

    # Compile the model with our custom Triplet Loss
    triplet_model.compile(optimizer='adam', loss=get_triplet_loss())
    
    print("\n--- Starting Training ---")
    
    # Custom training loop
    EPOCHS = 10
    STEPS_PER_EPOCH = 50
    for epoch in range(EPOCHS):
        print(f"Epoch {epoch+1}/{EPOCHS}")
        for step in range(STEPS_PER_EPOCH):
            # Generate a batch of triplets
            anchors, positives, negatives = generate_triplets(train_data, Batch_size, embedding_model)
            
            # Train the model on the triplet batch
            loss = triplet_model.train_on_batch(
                [anchors, positives, negatives],
                y=np.zeros(len(anchors)) # y_true is ignored by triplet loss, so we use dummy data
            )
            print(f"  Step {step+1}/{STEPS_PER_EPOCH}, Loss: {loss:.4f}")
            
    print("\n--- Training Complete ---")
# Out:
# --- Starting Training ---
# Epoch 1/10
#   Step 1/50, Loss: 19.9206
#   Step 2/50, Loss: 19.3309
#   Step 3/50, Loss: 27.5612
#   Step 4/50, Loss: 28.3178
#   Step 5/50, Loss: 31.7409
#   Step 6/50, Loss: 35.7341
#   Step 7/50, Loss: 41.0150
#   Step 8/50, Loss: 41.6133
#   Step 9/50, Loss: 42.2676
#   Step 10/50, Loss: 45.7333
#   Step 11/50, Loss: 45.1018
#   Step 12/50, Loss: 45.7017
#   Step 13/50, Loss: 43.6471
#   Step 14/50, Loss: 43.2570
#   Step 15/50, Loss: 41.9231
#   Step 16/50, Loss: 40.8208
#   Step 17/50, Loss: 39.6795
#   Step 18/50, Loss: 38.5118
#   Step 19/50, Loss: 37.8372
#   Step 20/50, Loss: 37.0636
#   Step 21/50, Loss: 36.2066
#   Step 22/50, Loss: 35.0594
#   Step 23/50, Loss: 34.2588
#   Step 24/50, Loss: 33.2150
#   Step 25/50, Loss: 32.1551
#   Step 26/50, Loss: 31.2609
#   Step 27/50, Loss: 30.2490
#   Step 28/50, Loss: 29.2580
#   Step 29/50, Loss: 28.3494
#   Step 30/50, Loss: 27.4502
#   Step 31/50, Loss: 26.6147
#   Step 32/50, Loss: 25.8153
#   Step 33/50, Loss: 25.0579
#   Step 34/50, Loss: 24.3413
#   Step 35/50, Loss: 23.6648
#   Step 36/50, Loss: 23.0260
#   Step 37/50, Loss: 22.4212
#   Step 38/50, Loss: 21.8464
#   Step 39/50, Loss: 21.3012
#   Step 40/50, Loss: 20.7832
#   Step 41/50, Loss: 20.2905
#   Step 42/50, Loss: 19.8213
#   Step 43/50, Loss: 19.3740
#   Step 44/50, Loss: 18.9469
#   Step 45/50, Loss: 18.5388
#   Step 46/50, Loss: 18.1484
#   Step 47/50, Loss: 17.7746
#   Step 48/50, Loss: 17.4162
#   Step 49/50, Loss: 17.0723
#   Step 50/50, Loss: 16.7421
# Epoch 2/10
#   Step 1/50, Loss: 16.4247
#   Step 2/50, Loss: 16.1195
#   Step 3/50, Loss: 15.8257
#   Step 4/50, Loss: 15.5427
#   Step 5/50, Loss: 15.2700
#   Step 6/50, Loss: 15.0070
#   Step 7/50, Loss: 14.7532
#   Step 8/50, Loss: 14.5080
#   Step 9/50, Loss: 14.2712
#   Step 10/50, Loss: 14.0422
#   Step 11/50, Loss: 13.8208
#   Step 12/50, Loss: 13.6065
#   Step 13/50, Loss: 13.3989
#   Step 14/50, Loss: 13.1978
#   Step 15/50, Loss: 13.0029
#   Step 16/50, Loss: 12.8138
#   Step 17/50, Loss: 12.6304
#   Step 18/50, Loss: 12.4523
#   Step 19/50, Loss: 12.2794
#   Step 20/50, Loss: 12.1114
#   Step 21/50, Loss: 11.9482
#   Step 22/50, Loss: 11.7894
#   Step 23/50, Loss: 11.6350
#   Step 24/50, Loss: 11.4847
#   Step 25/50, Loss: 11.3384
#   Step 26/50, Loss: 11.1959
#   Step 27/50, Loss: 11.0571
#   Step 28/50, Loss: 10.9219
#   Step 29/50, Loss: 10.7901
#   Step 30/50, Loss: 10.6616
#   Step 31/50, Loss: 10.5362
#   Step 32/50, Loss: 10.4138
#   Step 33/50, Loss: 10.2944
#   Step 34/50, Loss: 10.1779
#   Step 35/50, Loss: 10.0640
#   Step 36/50, Loss: 9.9528
#   Step 37/50, Loss: 9.8442
#   Step 38/50, Loss: 9.7380
#   Step 39/50, Loss: 9.6341
#   Step 40/50, Loss: 9.5326
#   Step 41/50, Loss: 9.4333
#   Step 42/50, Loss: 9.3361
#   Step 43/50, Loss: 9.2410
#   Step 44/50, Loss: 9.1480
#   Step 45/50, Loss: 9.0568
#   Step 46/50, Loss: 8.9676
#   Step 47/50, Loss: 8.8802
#   Step 48/50, Loss: 8.7946
#   Step 49/50, Loss: 8.7106
#   Step 50/50, Loss: 8.6284
# Epoch 3/10
#   Step 1/50, Loss: 8.5478
#   Step 2/50, Loss: 8.4687
#   Step 3/50, Loss: 8.3912
#   Step 4/50, Loss: 8.3151
#   Step 5/50, Loss: 8.2405
#   Step 6/50, Loss: 8.1673
#   Step 7/50, Loss: 8.0955
#   Step 8/50, Loss: 8.0250
#   Step 9/50, Loss: 7.9557
#   Step 10/50, Loss: 7.8878
#   Step 11/50, Loss: 7.8210
#   Step 12/50, Loss: 7.7554
#   Step 13/50, Loss: 7.6910
#   Step 14/50, Loss: 7.6277
#   Step 15/50, Loss: 7.5655
#   Step 16/50, Loss: 7.5043
#   Step 17/50, Loss: 7.4442
#   Step 18/50, Loss: 7.3851
#   Step 19/50, Loss: 7.3270
#   Step 20/50, Loss: 7.2698
#   Step 21/50, Loss: 7.2136
#   Step 22/50, Loss: 7.1583
#   Step 23/50, Loss: 7.1039
#   Step 24/50, Loss: 7.0504
#   Step 25/50, Loss: 6.9977
#   Step 26/50, Loss: 6.9459
#   Step 27/50, Loss: 6.8948
#   Step 28/50, Loss: 6.8446
#   Step 29/50, Loss: 6.7951
#   Step 30/50, Loss: 6.7464
#   Step 31/50, Loss: 6.6984
#   Step 32/50, Loss: 6.6511
#   Step 33/50, Loss: 6.6046
#   Step 34/50, Loss: 6.5587
#   Step 35/50, Loss: 6.5135
#   Step 36/50, Loss: 6.4690
#   Step 37/50, Loss: 6.4251
#   Step 38/50, Loss: 6.3818
#   Step 39/50, Loss: 6.3392
#   Step 40/50, Loss: 6.2972
#   Step 41/50, Loss: 6.2557
#   Step 42/50, Loss: 6.2148
#   Step 43/50, Loss: 6.1745
#   Step 44/50, Loss: 6.1348
#   Step 45/50, Loss: 6.0956
#   Step 46/50, Loss: 6.0569
#   Step 47/50, Loss: 6.0188
#   Step 48/50, Loss: 5.9811
#   Step 49/50, Loss: 5.9440
#   Step 50/50, Loss: 5.9074
# Epoch 4/10
#   Step 1/50, Loss: 5.8712
#   Step 2/50, Loss: 5.8355
#   Step 3/50, Loss: 5.8003
#   Step 4/50, Loss: 5.7655
#   Step 5/50, Loss: 5.7312
#   Step 6/50, Loss: 5.6973
#   Step 7/50, Loss: 5.6638
#   Step 8/50, Loss: 5.6307
#   Step 9/50, Loss: 5.5981
#   Step 10/50, Loss: 5.5659
#   Step 11/50, Loss: 5.5340
#   Step 12/50, Loss: 5.5026
#   Step 13/50, Loss: 5.4715
#   Step 14/50, Loss: 5.4408
#   Step 15/50, Loss: 5.4105
#   Step 16/50, Loss: 5.3805
#   Step 17/50, Loss: 5.3509
#   Step 18/50, Loss: 5.3217
#   Step 19/50, Loss: 5.2928
#   Step 20/50, Loss: 5.2642
#   Step 21/50, Loss: 5.2359
#   Step 22/50, Loss: 5.2080
#   Step 23/50, Loss: 5.1804
#   Step 24/50, Loss: 5.1531
#   Step 25/50, Loss: 5.1261
#   Step 26/50, Loss: 5.0995
#   Step 27/50, Loss: 5.0731
#   Step 28/50, Loss: 5.0470
#   Step 29/50, Loss: 5.0212
#   Step 30/50, Loss: 4.9957
#   Step 31/50, Loss: 4.9704
#   Step 32/50, Loss: 4.9455
#   Step 33/50, Loss: 4.9208
#   Step 34/50, Loss: 4.8964
#   Step 35/50, Loss: 4.8722
#   Step 36/50, Loss: 4.8483
#   Step 37/50, Loss: 4.8246
#   Step 38/50, Loss: 4.8012
#   Step 39/50, Loss: 4.7781
#   Step 40/50, Loss: 4.7551
#   Step 41/50, Loss: 4.7325
#   Step 42/50, Loss: 4.7100
#   Step 43/50, Loss: 4.6878
#   Step 44/50, Loss: 4.6658
#   Step 45/50, Loss: 4.6440
#   Step 46/50, Loss: 4.6225
#   Step 47/50, Loss: 4.6011
#   Step 48/50, Loss: 4.5800
#   Step 49/50, Loss: 4.5591
#   Step 50/50, Loss: 4.5384
# Epoch 5/10
#   Step 1/50, Loss: 4.5179
#   Step 2/50, Loss: 4.4976
#   Step 3/50, Loss: 4.4775
#   Step 4/50, Loss: 4.4576
#   Step 5/50, Loss: 4.4379
#   Step 6/50, Loss: 4.4183
#   Step 7/50, Loss: 4.3990
#   Step 8/50, Loss: 4.3798
#   Step 9/50, Loss: 4.3608
#   Step 10/50, Loss: 4.3420
#   Step 11/50, Loss: 4.3234
#   Step 12/50, Loss: 4.3050
#   Step 13/50, Loss: 4.2867
#   Step 14/50, Loss: 4.2686
#   Step 15/50, Loss: 4.2506
#   Step 16/50, Loss: 4.2328
#   Step 17/50, Loss: 4.2152
#   Step 18/50, Loss: 4.1978
#   Step 19/50, Loss: 4.1805
#   Step 20/50, Loss: 4.1633
#   Step 21/50, Loss: 4.1463
#   Step 22/50, Loss: 4.1295
#   Step 23/50, Loss: 4.1128
#   Step 24/50, Loss: 4.0962
#   Step 25/50, Loss: 4.0798
#   Step 26/50, Loss: 4.0636
#   Step 27/50, Loss: 4.0474
#   Step 28/50, Loss: 4.0315
#   Step 29/50, Loss: 4.0156
#   Step 30/50, Loss: 3.9999
#   Step 31/50, Loss: 3.9843
#   Step 32/50, Loss: 3.9689
#   Step 33/50, Loss: 3.9536
#   Step 34/50, Loss: 3.9384
#   Step 35/50, Loss: 3.9234
#   Step 36/50, Loss: 3.9084
#   Step 37/50, Loss: 3.8936
#   Step 38/50, Loss: 3.8789
#   Step 39/50, Loss: 3.8644
#   Step 40/50, Loss: 3.8499
#   Step 41/50, Loss: 3.8356
#   Step 42/50, Loss: 3.8214
#   Step 43/50, Loss: 3.8073
#   Step 44/50, Loss: 3.7934
#   Step 45/50, Loss: 3.7795
#   Step 46/50, Loss: 3.7657
#   Step 47/50, Loss: 3.7521
#   Step 48/50, Loss: 3.7386
#   Step 49/50, Loss: 3.7251
#   Step 50/50, Loss: 3.7118
# Epoch 6/10
#   Step 1/50, Loss: 3.6986
#   Step 2/50, Loss: 3.6855
#   Step 3/50, Loss: 3.6725
#   Step 4/50, Loss: 3.6595
#   Step 5/50, Loss: 3.6467
#   Step 6/50, Loss: 3.6340
#   Step 7/50, Loss: 3.6214
#   Step 8/50, Loss: 3.6089
#   Step 9/50, Loss: 3.5965
#   Step 10/50, Loss: 3.5841
#   Step 11/50, Loss: 3.5719
#   Step 12/50, Loss: 3.5597
#   Step 13/50, Loss: 3.5477
#   Step 14/50, Loss: 3.5357
#   Step 15/50, Loss: 3.5238
#   Step 16/50, Loss: 3.5121
#   Step 17/50, Loss: 3.5004
#   Step 18/50, Loss: 3.4887
#   Step 19/50, Loss: 3.4772
#   Step 20/50, Loss: 3.4658
#   Step 21/50, Loss: 3.4544
#   Step 22/50, Loss: 3.4431
#   Step 23/50, Loss: 3.4319
#   Step 24/50, Loss: 3.4208
#   Step 25/50, Loss: 3.4098
#   Step 26/50, Loss: 3.3988
#   Step 27/50, Loss: 3.3879
#   Step 28/50, Loss: 3.3771
#   Step 29/50, Loss: 3.3664
#   Step 30/50, Loss: 3.3557
#   Step 31/50, Loss: 3.3451
#   Step 32/50, Loss: 3.3346
#   Step 33/50, Loss: 3.3242
#   Step 34/50, Loss: 3.3138
#   Step 35/50, Loss: 3.3035
#   Step 36/50, Loss: 3.2933
#   Step 37/50, Loss: 3.2832
#   Step 38/50, Loss: 3.2731
#   Step 39/50, Loss: 3.2631
#   Step 40/50, Loss: 3.2531
#   Step 41/50, Loss: 3.2432
#   Step 42/50, Loss: 3.2334
#   Step 43/50, Loss: 3.2237
#   Step 44/50, Loss: 3.2140
#   Step 45/50, Loss: 3.2044
#   Step 46/50, Loss: 3.1948
#   Step 47/50, Loss: 3.1853
#   Step 48/50, Loss: 3.1759
#   Step 49/50, Loss: 3.1666
#   Step 50/50, Loss: 3.1572
# Epoch 7/10
#   Step 1/50, Loss: 3.1480
#   Step 2/50, Loss: 3.1388
#   Step 3/50, Loss: 3.1297
#   Step 4/50, Loss: 3.1206
#   Step 5/50, Loss: 3.1116
#   Step 6/50, Loss: 3.1027
#   Step 7/50, Loss: 3.0938
#   Step 8/50, Loss: 3.0850
#   Step 9/50, Loss: 3.0762
#   Step 10/50, Loss: 3.0675
#   Step 11/50, Loss: 3.0588
#   Step 12/50, Loss: 3.0502
#   Step 13/50, Loss: 3.0416
#   Step 14/50, Loss: 3.0331
#   Step 15/50, Loss: 3.0247
#   Step 16/50, Loss: 3.0163
#   Step 17/50, Loss: 3.0079
#   Step 18/50, Loss: 2.9996
#   Step 19/50, Loss: 2.9914
#   Step 20/50, Loss: 2.9832
#   Step 21/50, Loss: 2.9750
#   Step 22/50, Loss: 2.9669
#   Step 23/50, Loss: 2.9589
#   Step 24/50, Loss: 2.9509
#   Step 25/50, Loss: 2.9429
#   Step 26/50, Loss: 2.9350
#   Step 27/50, Loss: 2.9272
#   Step 28/50, Loss: 2.9194
#   Step 29/50, Loss: 2.9116
#   Step 30/50, Loss: 2.9039
#   Step 31/50, Loss: 2.8962
#   Step 32/50, Loss: 2.8886
#   Step 33/50, Loss: 2.8810
#   Step 34/50, Loss: 2.8735
#   Step 35/50, Loss: 2.8660
#   Step 36/50, Loss: 2.8585
#   Step 37/50, Loss: 2.8511
#   Step 38/50, Loss: 2.8438
#   Step 39/50, Loss: 2.8365
#   Step 40/50, Loss: 2.8292
#   Step 41/50, Loss: 2.8219
#   Step 42/50, Loss: 2.8148
#   Step 43/50, Loss: 2.8076
#   Step 44/50, Loss: 2.8005
#   Step 45/50, Loss: 2.7934
#   Step 46/50, Loss: 2.7864
#   Step 47/50, Loss: 2.7794
#   Step 48/50, Loss: 2.7724
#   Step 49/50, Loss: 2.7655
#   Step 50/50, Loss: 2.7587
# Epoch 8/10
#   Step 1/50, Loss: 2.7518
#   Step 2/50, Loss: 2.7450
#   Step 3/50, Loss: 2.7383
#   Step 4/50, Loss: 2.7315
#   Step 5/50, Loss: 2.7249
#   Step 6/50, Loss: 2.7182
#   Step 7/50, Loss: 2.7116
#   Step 8/50, Loss: 2.7050
#   Step 9/50, Loss: 2.6985
#   Step 10/50, Loss: 2.6920
#   Step 11/50, Loss: 2.6855
#   Step 12/50, Loss: 2.6791
#   Step 13/50, Loss: 2.6727
#   Step 14/50, Loss: 2.6663
#   Step 15/50, Loss: 2.6600
#   Step 16/50, Loss: 2.6537
#   Step 17/50, Loss: 2.6474
#   Step 18/50, Loss: 2.6412
#   Step 19/50, Loss: 2.6350
#   Step 20/50, Loss: 2.6288
#   Step 21/50, Loss: 2.6227
#   Step 22/50, Loss: 2.6166
#   Step 23/50, Loss: 2.6105
#   Step 24/50, Loss: 2.6045
#   Step 25/50, Loss: 2.5985
#   Step 26/50, Loss: 2.5925
#   Step 27/50, Loss: 2.5866
#   Step 28/50, Loss: 2.5806
#   Step 29/50, Loss: 2.5748
#   Step 30/50, Loss: 2.5689
#   Step 31/50, Loss: 2.5631
#   Step 32/50, Loss: 2.5573
#   Step 33/50, Loss: 2.5515
#   Step 34/50, Loss: 2.5458
#   Step 35/50, Loss: 2.5401
#   Step 36/50, Loss: 2.5344
#   Step 37/50, Loss: 2.5288
#   Step 38/50, Loss: 2.5232
#   Step 39/50, Loss: 2.5176
#   Step 40/50, Loss: 2.5120
#   Step 41/50, Loss: 2.5065
#   Step 42/50, Loss: 2.5010
#   Step 43/50, Loss: 2.4955
#   Step 44/50, Loss: 2.4900
#   Step 45/50, Loss: 2.4846
#   Step 46/50, Loss: 2.4792
#   Step 47/50, Loss: 2.4738
#   Step 48/50, Loss: 2.4685
#   Step 49/50, Loss: 2.4632
#   Step 50/50, Loss: 2.4579
# Epoch 9/10
#   Step 1/50, Loss: 2.4526
#   Step 2/50, Loss: 2.4474
#   Step 3/50, Loss: 2.4422
#   Step 4/50, Loss: 2.4370
#   Step 5/50, Loss: 2.4318
#   Step 6/50, Loss: 2.4267
#   Step 7/50, Loss: 2.4215
#   Step 8/50, Loss: 2.4164
#   Step 9/50, Loss: 2.4114
#   Step 10/50, Loss: 2.4063
#   Step 11/50, Loss: 2.4013
#   Step 12/50, Loss: 2.3963
#   Step 13/50, Loss: 2.3913
#   Step 14/50, Loss: 2.3864
#   Step 15/50, Loss: 2.3815
#   Step 16/50, Loss: 2.3766
#   Step 17/50, Loss: 2.3717
#   Step 18/50, Loss: 2.3668
#   Step 19/50, Loss: 2.3620
#   Step 20/50, Loss: 2.3572
#   Step 21/50, Loss: 2.3524
#   Step 22/50, Loss: 2.3476
#   Step 23/50, Loss: 2.3429
#   Step 24/50, Loss: 2.3382
#   Step 25/50, Loss: 2.3335
#   Step 26/50, Loss: 2.3288
#   Step 27/50, Loss: 2.3241
#   Step 28/50, Loss: 2.3195
#   Step 29/50, Loss: 2.3149
#   Step 30/50, Loss: 2.3103
#   Step 31/50, Loss: 2.3057
#   Step 32/50, Loss: 2.3011
#   Step 33/50, Loss: 2.2966
#   Step 34/50, Loss: 2.2921
#   Step 35/50, Loss: 2.2876
#   Step 36/50, Loss: 2.2831
#   Step 37/50, Loss: 2.2787
#   Step 38/50, Loss: 2.2742
#   Step 39/50, Loss: 2.2698
#   Step 40/50, Loss: 2.2654
#   Step 41/50, Loss: 2.2611
#   Step 42/50, Loss: 2.2567
#   Step 43/50, Loss: 2.2524
#   Step 44/50, Loss: 2.2481
#   Step 45/50, Loss: 2.2438
#   Step 46/50, Loss: 2.2395
#   Step 47/50, Loss: 2.2352
#   Step 48/50, Loss: 2.2310
#   Step 49/50, Loss: 2.2268
#   Step 50/50, Loss: 2.2225
# Epoch 10/10
#   Step 1/50, Loss: 2.2184
#   Step 2/50, Loss: 2.2142
#   Step 3/50, Loss: 2.2100
#   Step 4/50, Loss: 2.2059
#   Step 5/50, Loss: 2.2018
#   Step 6/50, Loss: 2.1977
#   Step 7/50, Loss: 2.1936
#   Step 8/50, Loss: 2.1895
#   Step 9/50, Loss: 2.1855
#   Step 10/50, Loss: 2.1815
#   Step 11/50, Loss: 2.1775
#   Step 12/50, Loss: 2.1735
#   Step 13/50, Loss: 2.1695
#   Step 14/50, Loss: 2.1655
#   Step 15/50, Loss: 2.1616
#   Step 16/50, Loss: 2.1577
#   Step 17/50, Loss: 2.1537
#   Step 18/50, Loss: 2.1498
#   Step 19/50, Loss: 2.1460
#   Step 20/50, Loss: 2.1421
#   Step 21/50, Loss: 2.1383
#   Step 22/50, Loss: 2.1344
#   Step 23/50, Loss: 2.1306
#   Step 24/50, Loss: 2.1268
#   Step 25/50, Loss: 2.1230
#   Step 26/50, Loss: 2.1193
#   Step 27/50, Loss: 2.1155
#   Step 28/50, Loss: 2.1118
#   Step 29/50, Loss: 2.1080
#   Step 30/50, Loss: 2.1043
#   Step 31/50, Loss: 2.1006
#   Step 32/50, Loss: 2.0970
#   Step 33/50, Loss: 2.0933
#   Step 34/50, Loss: 2.0896
#   Step 35/50, Loss: 2.0860
#   Step 36/50, Loss: 2.0824
#   Step 37/50, Loss: 2.0788
#   Step 38/50, Loss: 2.0752
#   Step 39/50, Loss: 2.0716
#   Step 40/50, Loss: 2.0681
#   Step 41/50, Loss: 2.0645
#   Step 42/50, Loss: 2.0610
#   Step 43/50, Loss: 2.0574
#   Step 44/50, Loss: 2.0539
#   Step 45/50, Loss: 2.0504
#   Step 46/50, Loss: 2.0470
#   Step 47/50, Loss: 2.0435
#   Step 48/50, Loss: 2.0401
#   Step 49/50, Loss: 2.0366
#   Step 50/50, Loss: 2.0332
#
# --- Training Complete ---

# %%
# Evaluate the model on the test data (1:1 Verification)
verify_faces(embedding_model, test_data)

# Demonstrate Face Identification (1:N Matching)
# We will use an image from a person in the test set as our "unknown" face
# and try to identify it against the entire database.

# Get a random person and a random image from that person for identification
if test_data and test_data['Angelina Jolie'] and len(test_data['Angelina Jolie']) > 1:
    unknown_image_path = test_data['Angelina Jolie'][1] # Using the second image as a test
    
    # We pass the entire test_data as our gallery of known faces
    identified_person = identify_person(embedding_model, test_data, unknown_image_path)
    
    print(f"Final Identification for {os.path.basename(unknown_image_path)}: {identified_person}")
else:
    print("\nCould not perform identification demonstration. Test data not structured as expected.")
# Out:
# -------- Verifying Faces ------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Verifying images for Angelina Jolie :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  Mathch : celebrity\Test\Angelina Jolie\002_8f8da10e.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Angelina Jolie\003_57612506.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Angelina Jolie\004_f61e7d0c.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#  Mathch : celebrity\Test\Angelina Jolie\085_f579db33.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Angelina Jolie\086_f2c730f3.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Angelina Jolie\087_f325890f.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Angelina Jolie\088_029ffc54.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Angelina Jolie\089_33e36564.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Angelina Jolie\090_da55509f.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Angelina Jolie\091_b5b4a62f.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Angelina Jolie\092_26130bb1.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#  Mathch : celebrity\Test\Angelina Jolie\093_6ce62543.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#  Mathch : celebrity\Test\Angelina Jolie\094_c255b703.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Angelina Jolie\095_0be163a1.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Angelina Jolie\096_75710434.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Angelina Jolie\097_9a6bf61f.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Angelina Jolie\098_dd1405fc.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#  Mathch : celebrity\Test\Angelina Jolie\099_c22d3e48.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Angelina Jolie\100_31ff9373.jpg -> Same Person (Angelina Jolie) . Distance : 0.0000
#
# Verifying images for Brad Pitt :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Brad Pitt\009_23c94f29.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Brad Pitt\010_08c44431.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Brad Pitt\011_270cd3ea.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Brad Pitt\012_8de7a736.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Brad Pitt\013_0c83ca91.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#  Mathch : celebrity\Test\Brad Pitt\014_871b0d80.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#  Mathch : celebrity\Test\Brad Pitt\015_82889ec9.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Brad Pitt\016_8bb23f7e.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
#  Mathch : celebrity\Test\Brad Pitt\017_4748675b.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  Mathch : celebrity\Test\Brad Pitt\018_136dbb40.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Brad Pitt\019_ddcd5687.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Brad Pitt\020_45c8d790.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Brad Pitt\021_143b276f.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Brad Pitt\022_a8206d1a.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#  Mathch : celebrity\Test\Brad Pitt\023_98d91529.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#  Mathch : celebrity\Test\Brad Pitt\024_54112f36.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Brad Pitt\025_25dc7dcf.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Brad Pitt\026_805241a7.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Brad Pitt\027_78f200c3.jpg -> Same Person (Brad Pitt) . Distance : 0.0000
#
# Verifying images for Denzel Washington :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Denzel Washington\031_2fe075a5.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Denzel Washington\032_a67c5aa8.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Denzel Washington\033_f49a691c.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Denzel Washington\034_e09c630c.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Denzel Washington\035_014caeb7.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Denzel Washington\036_7ec2e5de.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Denzel Washington\037_39f2db43.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#  Mathch : celebrity\Test\Denzel Washington\038_d967a9c7.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Denzel Washington\039_faa6425d.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  Mathch : celebrity\Test\Denzel Washington\040_e534b74f.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Denzel Washington\041_c8998bae.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Denzel Washington\042_b0c87dc0.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Denzel Washington\043_9bfd94a4.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  Mathch : celebrity\Test\Denzel Washington\044_c38d661d.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Denzel Washington\045_60fc8dc5.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  Mathch : celebrity\Test\Denzel Washington\046_b67077e0.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Denzel Washington\047_05f6a63f.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#  Mathch : celebrity\Test\Denzel Washington\048_cd8dc27d.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Denzel Washington\049_40f1ba49.jpg -> Same Person (Denzel Washington) . Distance : 0.0000
#
# Verifying images for Hugh Jackman :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  Mathch : celebrity\Test\Hugh Jackman\056_11835953.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#  Mathch : celebrity\Test\Hugh Jackman\057_6aecaa18.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#  Mathch : celebrity\Test\Hugh Jackman\058_48dcb96c.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#  Mathch : celebrity\Test\Hugh Jackman\059_aef6a0a8.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#  Mathch : celebrity\Test\Hugh Jackman\060_2b7fbba5.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#  Mathch : celebrity\Test\Hugh Jackman\061_2de5a089.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#  Mathch : celebrity\Test\Hugh Jackman\062_5db87e94.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#  Mathch : celebrity\Test\Hugh Jackman\063_6f1c7f3e.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  Mathch : celebrity\Test\Hugh Jackman\064_12d52b76.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Hugh Jackman\065_db7b31f5.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#  Mathch : celebrity\Test\Hugh Jackman\066_03ff28be.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  Mathch : celebrity\Test\Hugh Jackman\067_296269c3.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Hugh Jackman\068_474081ea.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Hugh Jackman\069_429fc9ee.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Hugh Jackman\070_e88788cd.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
#  Mathch : celebrity\Test\Hugh Jackman\071_071d0cfc.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#  Mathch : celebrity\Test\Hugh Jackman\072_c6df94c3.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#  Mathch : celebrity\Test\Hugh Jackman\073_812b8d10.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#  Mathch : celebrity\Test\Hugh Jackman\074_d205687c.jpg -> Same Person (Hugh Jackman) . Distance : 0.0000
#
# Verifying images for Jennifer Lawrence :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\082_2251d7b7.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\083_c22f1140.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\084_0f0f27e4.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\085_b2827d47.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\086_7ddf4f90.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\087_2fd20b9a.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\088_1229c0dd.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\089_152cf5f6.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\090_14fe77d5.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\091_e8f3497f.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\092_aebdc10e.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\093_07692aea.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\094_c0a66044.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\095_0ccffcb8.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\096_a0626390.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\097_f19b4cfc.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\098_fa237ecc.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\099_384306de.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Jennifer Lawrence\100_6882dc21.jpg -> Same Person (Jennifer Lawrence) . Distance : 0.0000
#
# Verifying images for Johnny Depp :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Johnny Depp\002_331d0423.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Johnny Depp\083_16b5e7ab.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Johnny Depp\084_3dcf601a.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Johnny Depp\085_e9f6ea07.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Johnny Depp\086_f052c533.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Johnny Depp\087_f9794152.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Johnny Depp\088_1fcc7b2c.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Johnny Depp\089_2f2e823a.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Johnny Depp\090_c5d1d9eb.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Johnny Depp\091_c3ad83af.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Johnny Depp\092_3943353c.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Johnny Depp\093_8cb84a89.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  Mathch : celebrity\Test\Johnny Depp\094_42a45a8d.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Johnny Depp\095_233dc3f2.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Johnny Depp\096_78a5a076.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Johnny Depp\097_11415581.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  Mathch : celebrity\Test\Johnny Depp\098_16b30dda.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  Mathch : celebrity\Test\Johnny Depp\099_d88c0793.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Johnny Depp\100_120c14bc.jpg -> Same Person (Johnny Depp) . Distance : 0.0000
#
# Verifying images for Kate Winslet :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Kate Winslet\008_6c01eb52.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Kate Winslet\009_07c15c37.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\010_6102c83d.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Kate Winslet\011_dbc62ba7.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Kate Winslet\012_a2bb90dc.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Kate Winslet\013_b59e4acc.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\014_76fd590c.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\015_3a0f9ec8.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\016_211776b6.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\017_fb53f84d.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\018_738a56fd.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Kate Winslet\019_4402a7fe.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Kate Winslet\020_a7a653f4.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Kate Winslet\021_40180588.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\022_6cc0e508.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Kate Winslet\023_06dbacd1.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\024_cc39b61d.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\025_0131eaa3.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Kate Winslet\026_92cdfd7c.jpg -> Same Person (Kate Winslet) . Distance : 0.0000
#
# Verifying images for Leonardo DiCaprio :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\033_312ea9ed.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\034_00c6d43e.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\035_ab7cf1c4.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\036_f5ea9e84.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\037_fe4d2d8f.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\038_b52784d4.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\039_d49e8191.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\040_3a2c98cd.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\041_c91b0923.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\042_bfbfd7d8.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\043_93a5e582.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\044_f13caf17.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\045_d074e61c.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\046_db08e5f7.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\047_ce57f03b.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\048_f82caaae.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\049_37f969c1.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\050_e7bdecc0.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  Mathch : celebrity\Test\Leonardo DiCaprio\051_38196d60.jpg -> Same Person (Leonardo DiCaprio) . Distance : 0.0000
#
# Verifying images for Megan Fox :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Megan Fox\055_9508128d.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Megan Fox\056_ce828b1f.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Megan Fox\057_d2d179a5.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Megan Fox\058_1b5b5422.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Megan Fox\059_d09c7676.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Megan Fox\060_f5a38fe0.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Megan Fox\061_d844ec74.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Megan Fox\062_2539f58f.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Megan Fox\063_10c723ae.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Megan Fox\064_61385762.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Megan Fox\065_016dc8e2.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Megan Fox\066_50092138.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Megan Fox\067_4017d5e9.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Megan Fox\068_b8b844e2.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Megan Fox\069_0ffb5c63.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Megan Fox\070_4de04405.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Megan Fox\071_d75194ff.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Megan Fox\072_5debf32c.jpg -> Same Person (Megan Fox) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#  Mathch : celebrity\Test\Megan Fox\073_b7f93635.jpg -> Same Person (Megan Fox) . Distance : 0.0000
#
# Verifying images for Natalie Portman :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Natalie Portman\082_6883328f.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Natalie Portman\083_7fc7beca.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Natalie Portman\084_9db2a724.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Natalie Portman\085_5abcaccb.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Natalie Portman\086_e6cb087e.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Natalie Portman\087_dabfb9e0.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Natalie Portman\088_c6c7b0b2.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Natalie Portman\089_7a22dd1d.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Natalie Portman\090_d2b11902.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Natalie Portman\091_6985bf33.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Natalie Portman\092_a67b993f.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Natalie Portman\093_dbb553bf.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Natalie Portman\094_6aec42c7.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Natalie Portman\095_00690f89.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Natalie Portman\096_e119e862.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Natalie Portman\097_ec4fe2e9.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Natalie Portman\098_d82741fc.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Natalie Portman\099_75aa5bcc.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Natalie Portman\100_f11d5057.jpg -> Same Person (Natalie Portman) . Distance : 0.0000
#
# Verifying images for Nicole Kidman :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Nicole Kidman\002_36285f46.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Nicole Kidman\083_b9c10851.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Nicole Kidman\084_1eb9844d.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Nicole Kidman\085_8f8cc791.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Nicole Kidman\086_9b7a99a3.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Nicole Kidman\087_32eed8da.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Nicole Kidman\088_fce81ee7.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Nicole Kidman\089_09b45d05.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Nicole Kidman\090_8252f095.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Nicole Kidman\091_d4af6789.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Nicole Kidman\092_62cd3fd3.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Nicole Kidman\093_874dd692.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Nicole Kidman\094_4c44e0ab.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Nicole Kidman\095_bf0ae200.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Nicole Kidman\096_5c89f563.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Nicole Kidman\097_d6f6f9cf.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Nicole Kidman\098_5224652a.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Nicole Kidman\099_015d5f74.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  Mathch : celebrity\Test\Nicole Kidman\100_8a6e3419.jpg -> Same Person (Nicole Kidman) . Distance : 0.0000
#
# Verifying images for Robert Downey Jr :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\007_ecb8599e.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\008_79cd0b7b.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\009_49237aa0.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\010_991a88dc.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\011_da108a07.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\012_e3dd7d69.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\013_9e49009e.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\014_75f93e62.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\015_76c98a92.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\016_375490e8.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\017_fd82d064.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\018_0d23eccd.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\019_ac261615.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\020_b12140b8.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\021_d1cfd3e9.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\022_64141160.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\023_51dce41c.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\024_db7504a3.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Robert Downey Jr\025_467e0866.jpg -> Same Person (Robert Downey Jr) . Distance : 0.0000
#
# Verifying images for Sandra Bullock :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Sandra Bullock\032_f3773aa6.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Sandra Bullock\033_bc82f2a9.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Sandra Bullock\034_3c156ed0.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Sandra Bullock\035_bc2e1105.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Sandra Bullock\036_701f7b42.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Sandra Bullock\037_c035b16e.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Sandra Bullock\038_254f6d4c.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Sandra Bullock\039_7654fd34.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Sandra Bullock\040_4b9bc437.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Sandra Bullock\041_642b1b15.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Sandra Bullock\042_d91db350.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Sandra Bullock\043_4f352240.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Sandra Bullock\044_49497c96.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Sandra Bullock\045_24ebd253.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Sandra Bullock\046_89b5683b.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  Mathch : celebrity\Test\Sandra Bullock\047_afa9bc7d.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Sandra Bullock\048_ee0ebb84.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Sandra Bullock\049_0ba44f0d.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Sandra Bullock\050_4bdc1f8a.jpg -> Same Person (Sandra Bullock) . Distance : 0.0000
#
# Verifying images for Scarlett Johansson :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\042_81d1cfae.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\043_46a213d0.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\044_df20e34a.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\045_6b008fbc.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\046_83629801.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\047_6ec9d887.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\048_85dcb79b.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\049_8398d25d.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\050_c8461888.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\051_f852bd6d.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\052_89d1073b.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\053_ec47a4c0.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\054_e93bb861.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\055_f6e1bf43.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\056_ec9b544d.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\057_317143a9.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\058_90a2b4d3.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\059_07020e9d.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\060_003a8f0c.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\061_bf06c582.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\062_c5a26020.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\063_61a5b737.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\064_4da75fb3.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\065_6b64e773.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\066_8e7dd66e.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\067_590b9254.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\068_45cbb6a4.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\069_da4a375a.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\070_f5ece24f.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\071_9a0f4b21.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\072_c7f23b07.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\073_884e445b.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\074_75c0c81a.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\075_e0b91ee3.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\076_6aac7281.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\077_776d5e0f.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\078_6b17a035.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\079_9f634689.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Scarlett Johansson\080_d7addbd8.jpg -> Same Person (Scarlett Johansson) . Distance : 0.0000
#
# Verifying images for Tom Cruise :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Tom Cruise\082_1ac0f1ee.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  Mathch : celebrity\Test\Tom Cruise\083_63bb9285.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Tom Cruise\084_31281f33.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Tom Cruise\085_698d9a21.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  Mathch : celebrity\Test\Tom Cruise\086_8a3c6af8.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  Mathch : celebrity\Test\Tom Cruise\087_8fff57dd.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  Mathch : celebrity\Test\Tom Cruise\088_fde7e34b.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Tom Cruise\089_20b122f3.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Tom Cruise\090_8f4eb0e6.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Tom Cruise\091_a9736a22.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Tom Cruise\092_53648816.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Tom Cruise\093_7e0d43d2.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Tom Cruise\094_2f713c67.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Tom Cruise\095_08f36cce.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Tom Cruise\096_b45f1da1.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Tom Cruise\097_914cebdd.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Tom Cruise\098_3790f566.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Tom Cruise\099_705dbe8c.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Tom Cruise\100_32a5d9d1.jpg -> Same Person (Tom Cruise) . Distance : 0.0000
#
# Verifying images for Tom Hanks :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Tom Hanks\005_dac94cfe.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Tom Hanks\006_a28f75e7.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Tom Hanks\007_ba0aa044.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Tom Hanks\008_74cd0628.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Tom Hanks\009_474a6b2e.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Tom Hanks\010_2181b5f4.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Tom Hanks\011_1c3b7dfd.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Tom Hanks\012_39efc245.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Tom Hanks\013_b87334b3.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Tom Hanks\014_ff388296.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Tom Hanks\015_782498ae.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Tom Hanks\016_edfda289.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Tom Hanks\017_e4dd8745.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Tom Hanks\018_b7231fad.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Tom Hanks\019_c332c45a.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Tom Hanks\020_0847e879.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Tom Hanks\021_b7e22acc.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Tom Hanks\022_df2ce089.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Tom Hanks\023_2029f686.jpg -> Same Person (Tom Hanks) . Distance : 0.0000
#
# Verifying images for Will Smith :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Will Smith\036_8751d89b.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Will Smith\037_17e4f89a.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Will Smith\038_b28dda4c.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Will Smith\039_3daa67cf.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#  Mathch : celebrity\Test\Will Smith\040_630a0d6a.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#  Mathch : celebrity\Test\Will Smith\041_bcfa1766.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Will Smith\042_f6cff42f.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Will Smith\043_33815e76.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  Mathch : celebrity\Test\Will Smith\044_988edbe9.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#  Mathch : celebrity\Test\Will Smith\045_810b690c.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
#  Mathch : celebrity\Test\Will Smith\046_6d5b1ed6.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  Mathch : celebrity\Test\Will Smith\047_dc7e1839.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Will Smith\048_bf9c2b11.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Will Smith\049_15a71c48.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Will Smith\050_f5bd72ba.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#  Mathch : celebrity\Test\Will Smith\051_1f3aede9.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  Mathch : celebrity\Test\Will Smith\052_f15c0c78.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  Mathch : celebrity\Test\Will Smith\053_8405b30f.jpg -> Same Person (Will Smith) . Distance : 0.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  Mathch : celebrity\Test\Will Smith\054_cbee29ae.jpg -> Same Person (Will Smith) . Distance : 0.0000
#
# --- Identifying 002_8f8da10e.jpg ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  Best Mathc : Angelina Jolie with distace 0.0000 (Below Threshold)
# Final Identification for 002_8f8da10e.jpg: Angelina Jolie
